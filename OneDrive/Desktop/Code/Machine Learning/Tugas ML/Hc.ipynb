# %% [markdown]
# # Online Retail

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12172\328324305.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_excel("online_retail.xlsx")

# %% [markdown]
# ### Check missing value

# %%
columns = ['Quantity','UnitPrice']
df[columns].isnull().sum()
# Out:
# Quantity     0
# UnitPrice    0
# dtype: int64

# %%
plt.scatter(df['Quantity'], df['UnitPrice'])
plt.xlabel('Quantity')
plt.ylabel('UnitPrice')
plt.title('Quantity vs UnitPrice')
plt.show()

# %%
import scipy.cluster.hierarchy as sch
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
reduced_df = pca.fit_transform(df[columns])

dendrogram = sch.dendrogram(sch.linkage(reduced_df, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Quantity')
plt.ylabel('UnitPrice')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 7
#       4 pca = PCA(n_components=2)
#       5 reduced_df = pca.fit_transform(df[columns])
# ----> 7 dendrogram = sch.dendrogram(sch.linkage(reduced_df, method = 'ward'))
#       8 plt.title('Dendrogram')
#       9 plt.xlabel('Quantity')
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\cluster\hierarchy.py:1024, in linkage(y, method, metric, optimal_ordering)
#    1018     if (y.shape[0] == y.shape[1] and np.allclose(np.diag(y), 0) and
#    1019             xp.all(y >= 0) and np.allclose(y, y.T)):
#    1020         warnings.warn('The symmetric non-negative hollow observation '
#    1021                       'matrix looks suspiciously like an uncondensed '
#    1022                       'distance matrix',
#    1023                       ClusterWarning, stacklevel=2)
# -> 1024     y = distance.pdist(y, metric)
#    1025     y = xp.asarray(y)
#    1026 else:
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\spatial\distance.py:2232, in pdist(X, metric, out, **kwargs)
#    2230 if metric_info is not None:
#    2231     pdist_fn = metric_info.pdist_func
# -> 2232     return pdist_fn(X, out=out, **kwargs)
#    2233 elif mstr.startswith("test_"):
#    2234     metric_info = _TEST_METRICS.get(mstr, None)
#
# MemoryError: Unable to allocate 1.07 TiB for an array with shape (146832411186,) and data type float64
